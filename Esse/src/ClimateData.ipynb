# %%
from all_imports import *

import _modules
# Out:
#  ### test init###

# %%
# Load the data from the CSV file into a DataFrame
data = pd.read_csv(r"C:\Users\gottk\OneDrive\Storage\Projects\2024-08-00_MTHCOM_Masterthesis-Outdoor-Comfort\Thesis\Figures\Methodology\Climate\CliamteData.CSV", header=0)

# Set the first row as column names
data.columns = data.iloc[0]
data = data[1:]  # Remove the first row as it's now redundant

display(data.head(5))
# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10, 6))

# Plot each category (minimum, mean, maximum) for each time period
for i in range(1, len(data.columns), 4):
    ax.plot(data.iloc[:, i:i+3], label=data.columns[i].split()[1])

# Add labels and title
ax.set_xlabel("Months")
ax.set_ylabel("Temperature (°C)")
ax.set_title("Average Surface Air Temperature Increase")

# Add legend
ax.legend()

# Show the plot
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# 0 Category Average Minimum Surface Air Temperature  \
# 1      Jan                                   23.61
# 2      Feb                                   23.73
# 3      Mar                                   24.27
# 4      Apr                                   24.35
# 5      May                                   24.83
#
# 0 Average Mean Surface Air Temperature  \
# 1                                26.97
# 2                                27.39
# 3                                27.93
# 4                                28.08
# 5                                28.36
#
# 0 Average Maximum Surface Air Temperature Precipitation  \
# 1                                   30.39        247.44
# 2                                    31.1         148.5
# 3                                   31.63        219.77
# 4                                   31.86         207.2
# 5                                   31.95        186.01
#
# 0 Average Minimum Surface Air Temperature  \
# ...
