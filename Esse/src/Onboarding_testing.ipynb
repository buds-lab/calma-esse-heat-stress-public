# %%
from all_imports import *

import _modules
# Out:
#  ### test init###

# %%
# <--- Config.py --->
#Store the not publicly available variables needed that are set in the config.py file
API_KEY = _modules.API_KEY

# %%
# Settings
YOUR_TIMEZONE = "Asia/Singapore"
ID_PARTICIPANT = "esse00"
ID_EXPERIMENT = "esse"
WEEKS = "100"

# Query data
payload = {
    "id_participant": ID_PARTICIPANT,
    "id_experiment": ID_EXPERIMENT,
    "weeks": WEEKS,
}
headers = {"Accept": "application/json", "x-api-key": API_KEY}
response = requests.get(
    "https://m7cy76lxmi.execute-api.ap-southeast-1.amazonaws.com/default/cozie-apple-researcher-read-influx",
    params=payload,
    headers=headers,
)
url = response.content

# Download zipped CSV file with Cozie data
with requests.get(url, stream=True) as r:
    with open("cozie.zip", "wb") as f:
        shutil.copyfileobj(r.raw, f)

# Convert zipped CSV file with Cozie to dataframe
with open("cozie.zip", "rb") as f:
    df = pd.read_csv(f, compression={"method": "zip", "archive_name": "sample.csv"})

df = df.drop(columns=["Unnamed: 0"])
df["index"] = pd.to_datetime(df["index"])
df = df.set_index("index")
df.index = df.index.tz_convert(YOUR_TIMEZONE)

headers= df.columns
#pprint(list(headers))


df_questions = df[df["ws_survey_count"].notna()]
headers = df_questions.reset_index().columns


headers = df_questions.columns
questions_ids = [header for header in headers if header.startswith("q_")]
questions_ids.append('id_participant')
#questions_ids.append('ws_heart_rate')

pprint(list(questions_ids))

display(df_questions[questions_ids])
# Out:
# C:\Users\gottk\AppData\Local\Temp\ipykernel_9492\3484615727.py:28: DtypeWarning: Columns (4,5,6,7,8,9,10,12,13,15,16,17,21,31,32,35,36,37,38,42,44,51,52,71,72,74,75,77,78,80,81,90,91,110,111,113,114,116,117,119,120,133,134,135,136) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f, compression={"method": "zip", "archive_name": "sample.csv"})
# ['q_comfort_behavioral',
#  'q_comfort_heatstress',
#  'q_comfort_humidity',
#  'q_comfort_ind-activity',
#  'q_comfort_out-activity',
#  'q_comfort_preference',
#  'q_comfort_sensation',
#  'q_comfort_sun',
#  'q_comfort_wind',
#  'q_environment_shade',
#  'q_general_location_area',
#  'q_general_location_change',
#  'q_general_location_envi',
#  'q_indoor_condition',
#  'id_participant']
#                                  q_comfort_behavioral q_comfort_heatstress  \
# index
# 2024-01-18 09:29:48.901000+08:00                  NaN                  NaN
# 2024-01-18 10:20:12.478000+08:00                  NaN                  NaN
# 2024-01-18 13:00:56.555000+08:00              Nothing                   No
# 2024-01-18 19:19:00.332000+08:00                  NaN                  NaN
# 2024-01-19 09:47:05.676000+08:00                  NaN                  NaN
# ...                                               ...                  ...
# 2024-02-15 11:27:13.562000+08:00              Nothing                   No
# 2024-02-15 11:31:44.110000+08:00              Nothing                   No
# 2024-02-15 11:34:43.668000+08:00              Nothing                   No
# 2024-02-15 11:39:25.395000+08:00              Nothing                   No
# 2024-02-15 11:45:09.759000+08:00              Nothing                   No
#
#                                  q_comfort_humidity q_comfort_ind-activity  \
# index
# 2024-01-18 09:29:48.901000+08:00                NaN                Sitting
# 2024-01-18 10:20:12.478000+08:00                NaN                Sitting
# 2024-01-18 13:00:56.555000+08:00              humid                    NaN
# 2024-01-18 19:19:00.332000+08:00                NaN                Sitting
# 2024-01-19 09:47:05.676000+08:00                NaN                Sitting
# ...                                             ...                    ...
# 2024-02-15 11:27:13.562000+08:00            neutral                    NaN
# 2024-02-15 11:31:44.110000+08:00            neutral                    NaN
# 2024-02-15 11:34:43.668000+08:00            neutral                    NaN
# 2024-02-15 11:39:25.395000+08:00            neutral                    NaN
# 2024-02-15 11:45:09.759000+08:00              humid                    NaN
#
#                                  q_comfort_out-activity q_comfort_preference  \
# index
# 2024-01-18 09:29:48.901000+08:00                    NaN               Cooler
# 2024-01-18 10:20:12.478000+08:00                    NaN            No Change
# 2024-01-18 13:00:56.555000+08:00                Sitting               Cooler
# 2024-01-18 19:19:00.332000+08:00                    NaN               Cooler
# 2024-01-19 09:47:05.676000+08:00                    NaN            No Change
# ...                                                 ...                  ...
# 2024-02-15 11:27:13.562000+08:00                Walking            No Change
# 2024-02-15 11:31:44.110000+08:00                Walking               Cooler
# 2024-02-15 11:34:43.668000+08:00                Walking            No Change
# 2024-02-15 11:39:25.395000+08:00                Walking            No Change
# 2024-02-15 11:45:09.759000+08:00                Walking               Cooler
#
#                                  q_comfort_sensation     q_comfort_sun  \
# index
# 2024-01-18 09:29:48.901000+08:00                 NaN               NaN
# 2024-01-18 10:20:12.478000+08:00                 NaN               NaN
# 2024-01-18 13:00:56.555000+08:00                warm  I am not exposed
# 2024-01-18 19:19:00.332000+08:00                 NaN               NaN
# 2024-01-19 09:47:05.676000+08:00                 NaN               NaN
# ...                                              ...               ...
# 2024-02-15 11:27:13.562000+08:00             neutral              weak
# 2024-02-15 11:31:44.110000+08:00       slightly warm              weak
# 2024-02-15 11:34:43.668000+08:00             neutral              weak
# 2024-02-15 11:39:25.395000+08:00       slightly warm              weak
# 2024-02-15 11:45:09.759000+08:00       slightly warm  I am not exposed
#
#                                  q_comfort_wind q_environment_shade  \
# index
# 2024-01-18 09:29:48.901000+08:00            NaN                 NaN
# 2024-01-18 10:20:12.478000+08:00            NaN                 NaN
# 2024-01-18 13:00:56.555000+08:00        neutral               Other
# 2024-01-18 19:19:00.332000+08:00            NaN                 NaN
# 2024-01-19 09:47:05.676000+08:00            NaN                 NaN
# ...                                         ...                 ...
# 2024-02-15 11:27:13.562000+08:00        neutral                 NaN
# 2024-02-15 11:31:44.110000+08:00          stale                 NaN
# 2024-02-15 11:34:43.668000+08:00        neutral                 NaN
# 2024-02-15 11:39:25.395000+08:00          stale                 NaN
# 2024-02-15 11:45:09.759000+08:00          stale  Shading Structures
#
#                                  q_general_location_area  \
# index
# 2024-01-18 09:29:48.901000+08:00                     Yes
# 2024-01-18 10:20:12.478000+08:00                     Yes
# 2024-01-18 13:00:56.555000+08:00                     Yes
# 2024-01-18 19:19:00.332000+08:00                     Yes
# 2024-01-19 09:47:05.676000+08:00                     Yes
# ...                                                  ...
# 2024-02-15 11:27:13.562000+08:00                     Yes
# 2024-02-15 11:31:44.110000+08:00                     Yes
# 2024-02-15 11:34:43.668000+08:00                     Yes
# 2024-02-15 11:39:25.395000+08:00                     Yes
# 2024-02-15 11:45:09.759000+08:00                     Yes
#
#                                      q_general_location_change  \
# index
# 2024-01-18 09:29:48.901000+08:00  I did not change my location
# 2024-01-18 10:20:12.478000+08:00  I did not change my location
# 2024-01-18 13:00:56.555000+08:00  I did not change my location
# 2024-01-18 19:19:00.332000+08:00           Less than 10min ago
# 2024-01-19 09:47:05.676000+08:00  I did not change my location
# ...                                                        ...
# 2024-02-15 11:27:13.562000+08:00           More than 15min ago
# 2024-02-15 11:31:44.110000+08:00           More than 15min ago
# 2024-02-15 11:34:43.668000+08:00           More than 15min ago
# 2024-02-15 11:39:25.395000+08:00           More than 15min ago
# 2024-02-15 11:45:09.759000+08:00           More than 15min ago
#
#                                  q_general_location_envi   q_indoor_condition  \
# index
# 2024-01-18 09:29:48.901000+08:00                  Indoor  Natural Ventilation
# 2024-01-18 10:20:12.478000+08:00                  Indoor  Natural Ventilation
# 2024-01-18 13:00:56.555000+08:00            Semi-Outdoor                  NaN
# 2024-01-18 19:19:00.332000+08:00                  Indoor      Air conditioned
# 2024-01-19 09:47:05.676000+08:00                  Indoor      Air conditioned
# ...                                                  ...                  ...
# 2024-02-15 11:27:13.562000+08:00                 Outdoor                  NaN
# 2024-02-15 11:31:44.110000+08:00                 Outdoor                  NaN
# 2024-02-15 11:34:43.668000+08:00                 Outdoor                  NaN
# 2024-02-15 11:39:25.395000+08:00                 Outdoor                  NaN
# 2024-02-15 11:45:09.759000+08:00                 Outdoor                  NaN
#
#                                  id_participant
# index
# 2024-01-18 09:29:48.901000+08:00         esse00
# 2024-01-18 10:20:12.478000+08:00         esse00
# 2024-01-18 13:00:56.555000+08:00         esse00
# 2024-01-18 19:19:00.332000+08:00         esse00
# 2024-01-19 09:47:05.676000+08:00         esse00
# ...                                         ...
# 2024-02-15 11:27:13.562000+08:00         esse00
# 2024-02-15 11:31:44.110000+08:00         esse00
# 2024-02-15 11:34:43.668000+08:00         esse00
# 2024-02-15 11:39:25.395000+08:00         esse00
# 2024-02-15 11:45:09.759000+08:00         esse00
#
# [79 rows x 15 columns]
